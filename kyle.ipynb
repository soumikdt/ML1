# %%
# !prosperity2bt my_trader.py 0
# Out:
# Backtesting my_trader.py on round 0 day -2
# 100%|####################################| 2000/2000 [00:00<00:00, 95910.36it/s]
# AMETHYSTS: 3,214
# STARFRUIT: 2,088
# Total profit: 5,302
#
# Successfully saved backtest results to backtests/2025-03-22_18-59-52.log

# %%
# !prosperity2bt Trader_strft_amth.py 0
# Out:
# Backtesting Trader_strft_amth.py on round 0 day -2
# 100%|####################################| 2000/2000 [00:00<00:00, 93391.46it/s]
# AMETHYSTS: 3,214
# STARFRUIT: 2,088
# Total profit: 5,302
#
# Successfully saved backtest results to backtests/2025-03-24_19-58-35.log
